# %%
import pandas as pd
import numpy as np

# %%
#import datasets
cause_of_death = pd.read_csv("1. annual-number-of-deaths-by-cause.csv")
n_of_death = pd.read_csv("2. number-of-deaths-by-age-group.csv")
medical_pract = pd.read_excel("3. Medical Doctors Per 10000 population.xlsx")
iso = pd.read_csv("4. ISO 3166_country-and-continent-codes-list-csv.csv")
world_pop = pd.read_csv("5. World Population.csv")
expenditure = pd.read_excel("6. Current health expenditure (% of GDP).xlsx")

# %%
cause_of_death.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Meningitis  Alzheimer's disease and other dementias  Parkinson's disease  \
# 0      2933.0                                   1402.0                450.0
# 1      2731.0                                   1424.0                455.0
# 2      2460.0                                   1449.0                460.0
# 3      2327.0                                   1508.0                473.0
# 4      2254.0                                   1544.0                482.0
#
#    Nutritional deficiencies  Malaria  Drowning  ...  Chronic kidney disease  \
# ...

# %%
medical_pract.head()
# Out:
#   Applied filters:\nLocation type is Country\nLANGUAGE_CODE is en\nIndicatorCode is HWF_0001, HWF_0002, HWF_0003, HWF_0004, or HWF_0005  \
# 0                                                NaN
# 1                                      IndicatorCode
# 2                                           HWF_0001
# 3                                           HWF_0001
# 4                                           HWF_0001
#
#                      Unnamed: 1          Unnamed: 2      Unnamed: 3  \
# 0                           NaN                 NaN             NaN
# 1                     Indicator  ParentLocationCode  ParentLocation
# 2  Medical doctors (per 10,000)                 AFR          Africa
# 3  Medical doctors (per 10,000)                 AFR          Africa
# 4  Medical doctors (per 10,000)                 AFR          Africa
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6        Unnamed: 7 Unnamed: 8
# 0           NaN        NaN        NaN               NaN        NaN
# ...

# %%
cause_of_death.describe()
# Out:
#               Year     Meningitis  Alzheimer's disease and other dementias  \
# count  7273.000000    6840.000000                             6.840000e+03
# mean   2004.425134    8213.149561                             2.736319e+04
# std       8.623572   34982.933895                             1.113146e+05
# min    1990.000000       0.000000                             0.000000e+00
# 25%    1997.000000      19.000000                             1.287500e+02
# 50%    2004.000000     150.500000                             8.455000e+02
# 75%    2012.000000    1622.250000                             4.251000e+03
# max    2019.000000  432524.000000                             1.623276e+06
#
#        Parkinson's disease  Nutritional deficiencies        Malaria  \
# count          6840.000000               6840.000000    6840.000000
# mean           6493.627339              11006.353947   18903.160234
# std           25767.447063              48289.687100   97346.780570
# ...

# %%
cause_of_death.shape
# Out:
# (7273, 36)

# %%
cause_of_death.isnull().sum()
# Out:
# Entity                                             0
# Code                                            1067
# Year                                               0
# Number of executions (Amnesty International)    7006
# Meningitis                                       433
# Alzheimer's disease and other dementias          433
# Parkinson's disease                              433
# Nutritional deficiencies                         433
# Malaria                                          433
# Drowning                                         433
# Interpersonal violence                           433
# Maternal disorders                               433
# HIV/AIDS                                         433
# Drug use disorders                               433
# Tuberculosis                                     433
# Cardiovascular diseases                          433
# Lower respiratory infections                     433
# Neonatal disorders                               433
# ...

# %%
n_of_death.head()
# Out:
#         Entity Code  Year  Deaths 70+ years  Deaths 50-69 years  \
# 0  Afghanistan  AFG  1990             34681               40624
# 1  Afghanistan  AFG  1991             35271               41414
# 2  Afghanistan  AFG  1992             35694               41829
# 3  Afghanistan  AFG  1993             36433               42598
# 4  Afghanistan  AFG  1994             37460               43923
#
#    Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# 0                    22968               5642           78170
# 1                    26523               6433           83035
# 2                    30000               6854           93859
# 3                    32339               7206          106537
# 4                    36817               8106          115334

# %%
n_of_death.isnull().sum()
# Out:
# Entity                       0
# Code                       690
# Year                         0
# Deaths 70+ years             0
# Deaths 50-69 years           0
# Deaths Age: 15-49 years      0
# Deaths 5-14 years            0
# Deaths Under 5               0
# dtype: int64

# %%
n_of_death.shape
# Out:
# (6840, 8)

# %%
# Drop rows with any empty cells
n_of_death.dropna(
    axis=0,
    how='any',
    thresh=None,
    subset=None,
    inplace=True
)

# %%
n_of_death.shape
# Out:
# (6150, 8)

# %% [markdown]
# # n_of_death is now clean

# %%
n_of_death.to_csv("c_no_of_death.csv")

# %%
n_of_death["Year"]
# Out:
# 0       1990
# 1       1991
# 2       1992
# 3       1993
# 4       1994
#         ...
# 6835    2015
# 6836    2016
# 6837    2017
# 6838    2018
# 6839    2019
# Name: Year, Length: 6150, dtype: int64

# %%
n_of_death.sample(10)
# Out:
#                     Entity Code  Year  Deaths 70+ years  Deaths 50-69 years  \
# 2660                 India  IND  2010           2704213             2428018
# 2              Afghanistan  AFG  1992             35694               41829
# 3665  Micronesia (country)  FSM  1995               229                 235
# 2048               Finland  FIN  1998             34241               10765
# 475             Bangladesh  BGD  2015            298982              220570
# 5203                Serbia  SRB  2003             69723               34896
# 638                Bermuda  BMU  1998               261                 124
# 4582      Papua New Guinea  PNG  2012             11109               15034
# 4435                  Oman  OMN  2015              4708                3606
# 1458               Czechia  CZE  2008             69440               29180
#
#       Deaths Age: 15-49 years  Deaths 5-14 years  Deaths Under 5
# 2660                  1759977             236617         1511841
# ...

# %%
n_of_death["Entity"].nunique()
# Out:
# 205

# %%
medical_pract.head()
# Out:
#   Applied filters:\nLocation type is Country\nLANGUAGE_CODE is en\nIndicatorCode is HWF_0001, HWF_0002, HWF_0003, HWF_0004, or HWF_0005  \
# 0                                                NaN
# 1                                      IndicatorCode
# 2                                           HWF_0001
# 3                                           HWF_0001
# 4                                           HWF_0001
#
#                      Unnamed: 1          Unnamed: 2      Unnamed: 3  \
# 0                           NaN                 NaN             NaN
# 1                     Indicator  ParentLocationCode  ParentLocation
# 2  Medical doctors (per 10,000)                 AFR          Africa
# 3  Medical doctors (per 10,000)                 AFR          Africa
# 4  Medical doctors (per 10,000)                 AFR          Africa
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6        Unnamed: 7 Unnamed: 8
# 0           NaN        NaN        NaN               NaN        NaN
# ...

# %%
medical_pract.shape
# Out:
# (11510, 9)

# %%
new_header = medical_pract.iloc[0] #grab the first row for the header
medical_pract = medical_pract[1:] #take the data less the header row
medical_pract.columns = new_header #set the header row as the df header

# %%
new_header = medical_pract.iloc[0] #grab the first row for the header
medical_pract = medical_pract[1:] #take the data less the header row
medical_pract.columns = new_header #set the header row as the df header

# %%
medical_pract.head()
# Out:
# 1 IndicatorCode                     Indicator ParentLocationCode  \
# 2      HWF_0001  Medical doctors (per 10,000)                AFR
# 3      HWF_0001  Medical doctors (per 10,000)                AFR
# 4      HWF_0001  Medical doctors (per 10,000)                AFR
# 5      HWF_0001  Medical doctors (per 10,000)                AFR
# 6      HWF_0001  Medical doctors (per 10,000)                AFR
#
# 1 ParentLocation ThreeLocCode Location Period FactValueNumeric Value
# 2         Africa          AGO   Angola   2018             2.14  2.14
# 3         Africa          AGO   Angola   2017             2.15  2.15
# 4         Africa          AGO   Angola   2009             1.31  1.31
# 5         Africa          AGO   Angola   2004             0.62  0.62
# 6         Africa          AGO   Angola   1997             0.59  0.59

# %%
medical_pract.shape
# Out:
# (11508, 9)

# %%
medical_pract.isnull().sum()
# Out:
# 1
# IndicatorCode         0
# Indicator             0
# ParentLocationCode    0
# ParentLocation        0
# ThreeLocCode          0
# Location              0
# Period                0
# FactValueNumeric      0
# Value                 0
# dtype: int64

# %%
medical_pract.to_csv("c_medical_pract.csv")

# %%
medical_pract.columns
# Out:
# Index(['IndicatorCode', 'Indicator', 'ParentLocationCode', 'ParentLocation',
#        'ThreeLocCode', 'Location', 'Period', 'FactValueNumeric', 'Value'],
#       dtype='object', name=1)

# %%
iso.shape
# Out:
# (254, 6)

# %%
medical_pract["ParentLocation"].value_counts()
# Out:
# Europe                   6402
# Africa                   1356
# Western Pacific          1259
# Americas                 1213
# Eastern Mediterranean     799
# South-East Asia           479
# Name: ParentLocation, dtype: int64

# %%
iso.isnull().sum()
# Out:
# Continent_Name                0
# Continent_Code               42
# Country_Name                  0
# Two_Letter_Country_Code       1
# Three_Letter_Country_Code     0
# Country_Number                4
# dtype: int64

# %%
iso.to_csv("c_iso.csv")

# %%
world_pop.head()
# Out:
#         Entity Code   Year  Population (historical estimates)
# 0  Afghanistan  AFG -10000                              14737
# 1  Afghanistan  AFG  -9000                              20405
# 2  Afghanistan  AFG  -8000                              28253
# 3  Afghanistan  AFG  -7000                              39120
# 4  Afghanistan  AFG  -6000                              54166

# %%
world_pop["Year"].sample(10)
# selecting rows based on condition 
world_pop_df = world_pop[world_pop['Year'] < 1990]

# %%
world_pop_df.shape
# Out:
# (48939, 4)

# %%
world_pop_df.isnull().sum()
# Out:
# Entity                                  0
# Code                                 2310
# Year                                    0
# Population (historical estimates)       0
# dtype: int64

# %%
world_pop_df.head()
# Out:
#         Entity Code   Year  Population (historical estimates)
# 0  Afghanistan  AFG -10000                              14737
# 1  Afghanistan  AFG  -9000                              20405
# 2  Afghanistan  AFG  -8000                              28253
# 3  Afghanistan  AFG  -7000                              39120
# 4  Afghanistan  AFG  -6000                              54166

# %%
world_pop_df["Year"].sample(10)
# selecting rows based on condition 
world_pop_df = world_pop_df[world_pop_df['Year'] >= 2019]

# %%
world_pop_df.head()
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Population (historical estimates)]
# Index: []

# %%
world_pop.sample(10)
# Out:
#                           Entity Code  Year  Population (historical estimates)
# 17201                    Finland  FIN  1962                            4492177
# 1205                     Andorra  AND  1818                               2654
# 51841                     Turkey  TUR  1935                           16409896
# 46649               South Africa  ZAF  1987                           36119328
# 42764  Saint Pierre and Miquelon  SPM  1965                               5171
# 34267                    Myanmar  MMR  1970                           27284118
# 15578                    Estonia  EST  1849                             473604
# 5208                     Belgium  BEL  1965                            9412091
# 12771                    Czechia  CZE  1889                            8651280
# 26465                 Kyrgyzstan  KGZ  1867                             813254

# %%
#selecting rows based on condition 
world_pop_less_than_20 = world_pop[world_pop['Year'] >= 2020]

# %%
world_pop_less_than_20.head()
# Out:
#           Entity Code  Year  Population (historical estimates)
# 257  Afghanistan  AFG  2020                           38972236
# 258  Afghanistan  AFG  2021                           40099460
# 516       Africa  NaN  2020                         1360677453
# 517       Africa  NaN  2021                         1393676724
# 775      Albania  ALB  2020                            2866850

# %%
world_pop_balance = world_pop_less_than_20[world_pop_less_than_20['Year'] <= 1989]

# %%
world_pop_less_than_20.to_csv("c_world_population.csv")

# %%
expenditure.head()
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date          2022-09-16 00:00:00
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                               Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                                    NaN         NaN         NaN         NaN
# 1                                    NaN         NaN         NaN         NaN
# 2                                    NaN         NaN         NaN         NaN
# 3                         Indicator Name      2000.0      2001.0      2002.0
# 4  Current health expenditure (% of GDP)         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 15  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# ...

# %%
expenditure.tail(10)
# Out:
#                Data Source World Development Indicators  \
# 260  Virgin Islands (U.S.)                          VIR
# 261                Vietnam                          VNM
# 262                Vanuatu                          VUT
# 263                  World                          WLD
# 264                  Samoa                          WSM
# 265                 Kosovo                          XKX
# 266            Yemen, Rep.                          YEM
# 267           South Africa                          ZAF
# 268                 Zambia                          ZMB
# 269               Zimbabwe                          ZWE
#
#                                 Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 260  Current health expenditure (% of GDP)         NaN         NaN
# 261  Current health expenditure (% of GDP)    3.819158    4.511307
# 262  Current health expenditure (% of GDP)    3.312522    3.393388
# 263  Current health expenditure (% of GDP)    8.630003    9.026567
# ...

# %%
new_header = expenditure.iloc[0] #grab the first row for the header
expenditure = expenditure[1:] #take the data less the header row
expenditure.columns = new_header #set the header row as the df header

# %%
expenditure.head()
# Out:
# 0                          NaN                  NaN  \
# 1            Last Updated Date  2022-09-16 00:00:00
# 2                          NaN                  NaN
# 3                 Country Name         Country Code
# 4                        Aruba                  ABW
# 5  Africa Eastern and Southern                  AFE
#
# 0                                    NaN          NaN          NaN  \
# 1                                    NaN          NaN          NaN
# 2                                    NaN          NaN          NaN
# 3                         Indicator Name  2000.000000  2001.000000
# 4  Current health expenditure (% of GDP)          NaN          NaN
# 5  Current health expenditure (% of GDP)     6.252428     6.390627
#
# 0          NaN          NaN          NaN          NaN          NaN  ...  \
# 1          NaN          NaN          NaN          NaN          NaN  ...
# 2          NaN          NaN          NaN          NaN          NaN  ...
# ...

# %%
new_header = expenditure.iloc[0] #grab the first row for the header
expenditure = expenditure[1:] #take the data less the header row
expenditure.columns = new_header #set the header row as the df header

new_header = expenditure.iloc[0] #grab the first row for the header
expenditure = expenditure[1:] #take the data less the header row
expenditure.columns = new_header #set the header row as the df header

# %%
new_header = expenditure.iloc[0] #grab the first row for the header
expenditure = expenditure[1:] #take the data less the header row
expenditure.columns = new_header #set the header row as the df header

# %%
expenditure.head()
# Out:
# 3                 Country Name Country Code  \
# 4                        Aruba          ABW
# 5  Africa Eastern and Southern          AFE
# 6                  Afghanistan          AFG
# 7   Africa Western and Central          AFW
# 8                       Angola          AGO
#
# 3                         Indicator Name    2000.0    2001.0    2002.0  \
# 4  Current health expenditure (% of GDP)       NaN       NaN       NaN
# 5  Current health expenditure (% of GDP)  6.252428  6.390627  5.969416
# 6  Current health expenditure (% of GDP)       NaN       NaN  9.443390
# 7  Current health expenditure (% of GDP)  3.771302  3.770256  3.387634
# 8  Current health expenditure (% of GDP)  1.908599  4.483516  3.329461
#
# 3    2003.0    2004.0    2005.0     2006.0  ...    2012.0    2013.0    2014.0  \
# 4       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 5  6.635666  6.710734  6.528098   6.492506  ...  6.562794  6.565689  6.152063
# ...

# %%
expenditure.isnull().sum()
# Out:
# 3
# Country Name        0
# Country Code        0
# Indicator Name      0
# 2000.0             34
# 2001.0             34
# 2002.0             33
# 2003.0             31
# 2004.0             31
# 2005.0             31
# 2006.0             31
# 2007.0             31
# 2008.0             31
# 2009.0             31
# 2010.0             30
# 2011.0             29
# 2012.0             30
# 2013.0             31
# 2014.0             31
# 2015.0             31
# 2016.0             32
# 2017.0             31
# 2018.0             31
# 2019.0             32
# 2020.0            266
# 2021.0            266
# dtype: int64

# %%
expenditure.columns
# Out:
# Index([  'Country Name',   'Country Code', 'Indicator Name',           2000.0,
#                  2001.0,           2002.0,           2003.0,           2004.0,
#                  2005.0,           2006.0,           2007.0,           2008.0,
#                  2009.0,           2010.0,           2011.0,           2012.0,
#                  2013.0,           2014.0,           2015.0,           2016.0,
#                  2017.0,           2018.0,           2019.0,           2020.0,
#                  2021.0],
#       dtype='object', name=3)

# %%
# create a dictionary
# key = old name
# value = new name
dict = {
        2000.0: '2000',
        2001.0: '2001',
        2002.0: '2002',
        2003.0: '2003',
        2004.0: '2004',
        2005.0: '2005',
        2006.0: '2006',
        2007.0: '2007',
        2008.0: '2008',
        2009.0: '2009',
        2010.0: '2010',
        2011.0: '2011',
        2012.0: '2012',
        2013.0: '2013',
        2014.0: '2014',
        2015.0: '2015',
        2016.0: '2016',
        2017.0: '2017',
        2018.0: '2018',
        2019.0: '2019',
        2020.0: '2020',
        2021.0: '2021',
        
       }
# call rename () method
expenditure.rename(columns=dict,
          inplace=True)

# %%
expenditure.sample(10)
# Out:
# 3        Country Name Country Code                         Indicator Name  \
# 36             Bhutan          BTN  Current health expenditure (% of GDP)
# 193  Papua New Guinea          PNG  Current health expenditure (% of GDP)
# 120             Italy          ITA  Current health expenditure (% of GDP)
# 134           Lebanon          LBN  Current health expenditure (% of GDP)
# 44              China          CHN  Current health expenditure (% of GDP)
# 208        South Asia          SAS  Current health expenditure (% of GDP)
# 128          Kiribati          KIR  Current health expenditure (% of GDP)
# 153            Monaco          MCO  Current health expenditure (% of GDP)
# 216        San Marino          SMR  Current health expenditure (% of GDP)
# 254           Uruguay          URY  Current health expenditure (% of GDP)
#
# 3         2000       2001       2002       2003       2004       2005  \
# 36    4.446843   5.004200   4.595636   4.129381   4.597773   4.134164
# ...

# %%
expenditure.head()
# Out:
# 3                 Country Name Country Code  \
# 4                        Aruba          ABW
# 5  Africa Eastern and Southern          AFE
# 6                  Afghanistan          AFG
# 7   Africa Western and Central          AFW
# 8                       Angola          AGO
#
# 3                         Indicator Name      2000      2001      2002  \
# 4  Current health expenditure (% of GDP)       NaN       NaN       NaN
# 5  Current health expenditure (% of GDP)  6.252428  6.390627  5.969416
# 6  Current health expenditure (% of GDP)       NaN       NaN  9.443390
# 7  Current health expenditure (% of GDP)  3.771302  3.770256  3.387634
# 8  Current health expenditure (% of GDP)  1.908599  4.483516  3.329461
#
# 3      2003      2004      2005       2006  ...      2012      2013      2014  \
# 4       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 5  6.635666  6.710734  6.528098   6.492506  ...  6.562794  6.565689  6.152063
# ...

# %%
expenditure.isna().sum()
# Out:
# 3
# Country Name        0
# Country Code        0
# Indicator Name      0
# 2000               34
# 2001               34
# 2002               33
# 2003               31
# 2004               31
# 2005               31
# 2006               31
# 2007               31
# 2008               31
# 2009               31
# 2010               30
# 2011               29
# 2012               30
# 2013               31
# 2014               31
# 2015               31
# 2016               32
# 2017               31
# 2018               31
# 2019               32
# 2020              266
# 2021              266
# dtype: int64

# %%
expenditure.shape
# Out:
# (266, 25)

# %%
n_expenditure = expenditure.drop(['2020', '2021'], axis=1)

# %%
n_expenditure.head()
# Out:
# 3                 Country Name Country Code  \
# 4                        Aruba          ABW
# 5  Africa Eastern and Southern          AFE
# 6                  Afghanistan          AFG
# 7   Africa Western and Central          AFW
# 8                       Angola          AGO
#
# 3                         Indicator Name      2000      2001      2002  \
# 4  Current health expenditure (% of GDP)       NaN       NaN       NaN
# 5  Current health expenditure (% of GDP)  6.252428  6.390627  5.969416
# 6  Current health expenditure (% of GDP)       NaN       NaN  9.443390
# 7  Current health expenditure (% of GDP)  3.771302  3.770256  3.387634
# 8  Current health expenditure (% of GDP)  1.908599  4.483516  3.329461
#
# 3      2003      2004      2005       2006  ...      2010      2011      2012  \
# 4       NaN       NaN       NaN        NaN  ...       NaN       NaN       NaN
# 5  6.635666  6.710734  6.528098   6.492506  ...  6.922891  6.773979  6.562794
# ...

# %%
n_expenditure.to_csv("c_expenditure.csv")

# %%
cause_of_death
# Out:
#            Entity Code  Year Number of executions (Amnesty International)  \
# 0     Afghanistan  AFG  2007                                           15
# 1     Afghanistan  AFG  2008                                           17
# 2     Afghanistan  AFG  2009                                            0
# 3     Afghanistan  AFG  2011                                            2
# 4     Afghanistan  AFG  2012                                           14
# ...           ...  ...   ...                                          ...
# 7268     Zimbabwe  ZWE  2015                                          NaN
# 7269     Zimbabwe  ZWE  2016                                          NaN
# 7270     Zimbabwe  ZWE  2017                                          NaN
# 7271     Zimbabwe  ZWE  2018                                          NaN
# 7272     Zimbabwe  ZWE  2019                                          NaN
#
#       Meningitis  Alzheimer's disease and other dementias  \
# ...

# %%
cause_of_death.isnull().sum()
# Out:
# Entity                                             0
# Code                                            1067
# Year                                               0
# Number of executions (Amnesty International)    7006
# Meningitis                                       433
# Alzheimer's disease and other dementias          433
# Parkinson's disease                              433
# Nutritional deficiencies                         433
# Malaria                                          433
# Drowning                                         433
# Interpersonal violence                           433
# Maternal disorders                               433
# HIV/AIDS                                         433
# Drug use disorders                               433
# Tuberculosis                                     433
# Cardiovascular diseases                          433
# Lower respiratory infections                     433
# Neonatal disorders                               433
# ...

# %%
cause_of_death.isna().sum()
# Out:
# Entity                                             0
# Code                                            1067
# Year                                               0
# Number of executions (Amnesty International)    7006
# Meningitis                                       433
# Alzheimer's disease and other dementias          433
# Parkinson's disease                              433
# Nutritional deficiencies                         433
# Malaria                                          433
# Drowning                                         433
# Interpersonal violence                           433
# Maternal disorders                               433
# HIV/AIDS                                         433
# Drug use disorders                               433
# Tuberculosis                                     433
# Cardiovascular diseases                          433
# Lower respiratory infections                     433
# Neonatal disorders                               433
# ...

# %%
cause_of_death.head()
# Out:
#         Entity Code  Year Number of executions (Amnesty International)  \
# 0  Afghanistan  AFG  2007                                           15
# 1  Afghanistan  AFG  2008                                           17
# 2  Afghanistan  AFG  2009                                            0
# 3  Afghanistan  AFG  2011                                            2
# 4  Afghanistan  AFG  2012                                           14
#
#    Meningitis  Alzheimer's disease and other dementias  Parkinson's disease  \
# 0      2933.0                                   1402.0                450.0
# 1      2731.0                                   1424.0                455.0
# 2      2460.0                                   1449.0                460.0
# 3      2327.0                                   1508.0                473.0
# 4      2254.0                                   1544.0                482.0
#
#    Nutritional deficiencies  Malaria  Drowning  ...  Chronic kidney disease  \
# ...

# %%
world_pop_less_than_20.head()
# Out:
#           Entity Code  Year  Population (historical estimates)
# 257  Afghanistan  AFG  2020                           38972236
# 258  Afghanistan  AFG  2021                           40099460
# 516       Africa  NaN  2020                         1360677453
# 517       Africa  NaN  2021                         1393676724
# 775      Albania  ALB  2020                            2866850

# %%
world_pop_less_than_20.shape
# Out:
# (496, 4)
